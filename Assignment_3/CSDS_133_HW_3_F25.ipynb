# %% [markdown]
# # CSDS 133: Introduction to Data Science and Engineering
# ## Fall 2024
# ## Homework - 3
# ## Due: 11.59.59pm Sunday October 13, 2024
#
# #### We learn two ways to collect data: API and Webscraping. In this assingment, you will collect data both with API and Web Scraping methods. Once you collect your data, you will create a Data Frame from the data and run basic statistics on your data (same as HW2 question 20). Then you will visualize your data choosing the best chart type.
#
# #### Note: you are NOT allowed to use any of the examples posted in the class Canvas page. This assingment is to encourge you to find your resourse rahter than testing your ability/understanding. This could be a perfect exercise for your class project data collection.

# %% [markdown]
# #### 1. Describe your data by answering following questions (API):
#
# 1- Data source:
#
# 2- Url for the source:
#
# 3- Describe your data (what is collected) :

# %% [markdown]
# #### 1. a.  Data collection code:
#
# 1- Briefly describe your data collection code source (class, online, self-created):

# %%
# Code for data collection
from mal import client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Code for data collection
# ----> 2 from mal import client
#
# ModuleNotFoundError: No module named 'mal'

# %% [markdown]
# #### 1.b. Store your data into data frame:

# %%
# Code for storing data into data frame

# %% [markdown]
# #### 1.c. Run basic statistics on the converted data (same as hw1- Q20):
# 1. Mean
# 2. Maximum
# 3. Minimum
# 4. Standard deviation
# 5. Median
# 6. 25th percentile
# 7. 75th percentile

# %%
# Code for basic statisitcs

# %% [markdown]
# #### 1.d Visualize your data:
# Describe your visualization by answering following questions:
# 1- Which chart type did you use to visualize your data?
# 2- Why did you choose this chart type?
#
# ##### NOTE: Your chart has to contain all necessary components (title, labels, legends, ...).

# %%
# Code for data visualization

# %% [markdown]
# #### 2. Describe your data by answering following questions (Web Scraping):
#
# 1- Data source:
#
# 2- Url for the source:
#
# 3- Describe your data (what is collected) :

# %% [markdown]
# #### 2. a.  Data collection code:
#
# 1- Briefly describe your data collection code source (class, online, self-created):

# %%
# Code for data collection

# %% [markdown]
# #### 2.b. Store your data into data frame:

# %%
# Code for storing data into data frame

# %% [markdown]
# #### 2.c. Run basic statistics on the converted data (same as hw1- Q20):
# 1. Mean
# 2. Maximum
# 3. Minimum
# 4. Standard deviation
# 5. Median
# 6. 25th percentile
# 7. 75th percentile

# %%
# Code for basic statisitcs

# %% [markdown]
# #### 2.d Visualize your data:
# Describe your visualization by answering following questions:
# 1- Which chart type did you use to visualize your data?
# 2- Why did you choose this chart type?
#
# ##### NOTE: Your chart has to contain all necessary components (title, labels, legends, ...).

# %%
# Code for data visualization
