# %% [markdown]
# # CSDS 133: Introduction to Data Science for Engineering Majors
# ## Fall 2025
# ## Homework - 2: Data Analysis with Scikit-Learn Datasets
# ## Due: 11:59PM Friday, October 3
#
# #### There are in total 20 questions that are followed by a blank cell. Please fill in the code in the blank cell, and remember to display the result. You are allowed to use class notebooks. Submit your notebook.
#
# This assignment focuses on **advanced data manipulation and analysis** using classic machine learning datasets from scikit-learn. You will work with three different types of data: botanical measurements (Iris), medical predictions (Diabetes), and image recognition (Handwritten Digits).
#
# **Important Notes:**
# - This assignment requires more complex thinking than Assignment #1
# - You'll be working with real machine learning datasets used in research and industry
# - Focus on understanding the data patterns and relationships
# - Each question includes references to relevant lecture materials
# - Because Jupyter Notebook will save the result of all codes that were executed before, if you are not sure whether your code is right and it may jeopardize the dataset ( for example: deleting some records), there are several ways to reset your data:
#   * Rerun the cell that creates the data
#   * Delete your current cell or comment it, and select "restart & run all" in the Kernel menu.
#   * Create a temporary variable that exactly copies the original dataframe, and test your codes on the temporary dataframe first.

# %% [markdown]
# #### 1. Import all necessary libraries: `numpy` as `np`, `pandas` as `pd`, `matplotlib.pyplot` as `plt`, and `sklearn.datasets` for loading the datasets. Set up matplotlib for inline plotting.
#
# **Lecture References:**
# - Week2/PythonBasics.ipynb: Section 1 (Python library import)
# - Week3/PythonBasics.ipynb: Section 1 (Python library import)
# - Week4/Pandas.ipynb: Import statements and setup

# %% [markdown]
# ## Section 1: Iris Dataset Analysis (Botanical Classification)
# The Iris dataset contains measurements of 150 iris flowers from 3 different species. This is one of the most famous datasets in data science!

# %% [markdown]
# #### 2. Load the Iris dataset using `sklearn.datasets.load_iris()`. Create a pandas DataFrame with the feature data and add the target labels as a new column called 'species'. Display the first 10 rows and basic information about the dataset.
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Section 1.2 (DataFrame Object), creating DataFrames from arrays
# - Week4/Pandas.ipynb: Section 4.1 (Loading data into DataFrame)
# - Week4/Pandas.ipynb: head() and info() methods for data exploration

# %% [markdown]
# #### 3. Explore the Iris dataset structure. How many samples are there of each species? Create a summary showing the count of each species and calculate basic statistics (mean, std, min, max) for each feature by species.
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Section 2 (Operating on Data)
# - Week4/Pandas.ipynb: Statistical summary using describe() method
# - Week4/Pandas.ipynb: Grouping operations and aggregations
#
# **Key functions to use**
# - `pd.DataFrame.value_counts()`
# - `pd.DataFrame.describe()`

# %% [markdown]
# #### 4. Create visualizations to understand feature relationships. Make a 2x2 subplot showing:
# - Histogram of sepal length by species
# - Histogram of sepal width by species
# - Histogram of petal length by species
# - Histogram of petal width by species
#
# Use different colors for each species and add appropriate labels.
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Example 1 (matplotlib.pyplot for plotting)
# - Week3/NumPy.ipynb: Example 1 (matplotlib histogram plotting)

# %% [markdown]
# #### 5. Create a scatter plot matrix comparing petal length vs petal width, colored by species. Which species can be easily separated based on petal measurements? Calculate the correlation coefficient between petal length and petal width for each species.
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Example 2 - correlation analysis and visualization
# - Week3/NumPy.ipynb: Section 1.2.5 (Aggregations) - correlation calculations
#
#
# **Key functions to use**
# - `matplotlib.pyplot.scatter()`
# - `numpy.corrcoef()`

# %% [markdown]
# #### 6. Feature engineering: Create a new feature called 'petal_area' (petal_length × petal_width) and 'sepal_area' (sepal_length × sepal_width). Which area measurement better discriminates between species?
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.2.1 (Array arithmetic) - element-wise multiplication
# - Week4/Pandas.ipynb: Adding new columns to DataFrames
# - Week4/Pandas.ipynb: Statistical analysis methods (describe)

# %% [markdown]
# #### 7. Advanced analysis: Identify outliers in the Iris dataset using the IQR method (values beyond Q1-1.5×IQR or Q3+1.5×IQR) for each feature. Which species and which features have the most outliers?
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.2.5 (Aggregations) - percentiles
# - Week4/Pandas.ipynb: Statistical functions and percentile calculations
# - Week3/NumPy.ipynb: Boolean masking for filtering data

# %% [markdown]
# ## Section 2: Diabetes Dataset Analysis (Medical Regression)
# The diabetes dataset contains health measurements from 442 patients, with the goal of predicting disease progression.

# %% [markdown]
# #### 8. Load the diabetes dataset using `sklearn.datasets.load_diabetes()`. Create a pandas DataFrame and examine the feature names and target variable. The features are already standardized. Display basic statistics and check for missing values.
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Section 1.2 (DataFrame Object) - creating DataFrames
# - Week4/Pandas.ipynb: Section 3.1 (Operating on Null Values) - checking for missing values
# - Week4/Pandas.ipynb: describe() method for statistical summaries

# %% [markdown]
# #### 9. Analyze feature correlations with the target variable (disease progression). Create a bar chart showing the correlation coefficient between each feature and the target. Which features are most strongly correlated with disease progression?
#
# **Key Functions to Use:**
# - `DataFrame.corr()`: Calculate correlation coefficients between variables
# - `plt.bar()` or `DataFrame.plot.bar()`: Create bar charts for visualization
# - `abs()`: Find absolute values to identify strongest correlations regardless of direction
#
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Correlation analysis methods
# - Week4/Pandas.ipynb: Example 2 - correlation visualization techniques
# - Week3/NumPy.ipynb: Example 1 - bar chart creation with matplotlib

# %% [markdown]
# #### 10. Create scatter plots of the three most correlated features vs. the target variable. Add trend lines to visualize the relationships. Calculate the R-squared values to quantify the strength of these relationships.
#
# **Key Functions to Use:**
# - `plt.scatter()`: Create scatter plots to visualize relationships between variables
# - `np.polyfit()`: Calculate coefficients for linear trend lines. Degree 1 is linear.
# - `np.poly1d()`: Create polynomial functions from coefficients for plotting trend lines
# - `np.corrcoef()`: Calculate correlation coefficients, which can be squared for R-squared values
#
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Example 2 - trend analysis and visualization
# - Week3/NumPy.ipynb: Section 1.2.5 - statistical calculations
#
#
# Hint: start with linear trend lines (degree = 1) with `polyfit` and then use `poly1d` to create a plottable function.

# %% [markdown]
# #### 11. Patient categorization: Create categories for disease progression:
# - 'Low' (target < 100)
# - 'Medium' (100 ≤ target < 200)
# - 'High' (target ≥ 200)
#
# Analyze the average feature values for each category. Which features show the most dramatic differences between categories?
#
# **Lecture References:**
# - Week2/PythonBasics.ipynb: Section 8 (If Statements) - conditional logic
# - Week4/Pandas.ipynb: Creating categorical variables and groupby operations
# - Week4/Pandas.ipynb: Aggregation and statistical analysis by groups

# %% [markdown]
# #### 12. Create a correlation heatmap for all diabetes features. Identify pairs of features that are highly correlated (|correlation| > 0.5). What does this tell us about potential redundancy in the data?
#
# **Key Functions to Use:**
# - `DataFrame.corr()`: Calculate correlation matrix between all features
# - `plt.imshow()` or `plt.matshow()`: Display correlation matrix as a heatmap
# - `plt.colorbar()`: Add color scale to interpret correlation values
# - `abs()`: Calculate absolute values to find strong correlations regardless of direction
#
#
# **Lecture References:**
# - Week4/Pandas.ipynb: Correlation analysis methods
# - Week3/NumPy.ipynb: Example 2 - heatmap visualization with matplotlib
# - Week4/Pandas.ipynb: Data analysis and interpretation techniques

# %% [markdown]
# ## Section 3: Handwritten Digits Analysis (Image Recognition)
# The digits dataset contains 8x8 pixel images of handwritten digits (0-9). This introduces you to image data analysis!

# %% [markdown]
# #### 13. Load the digits dataset using `sklearn.datasets.load_digits()`. Examine the data structure: how many samples, what are the dimensions, and how are the images stored? Display the first 10 digit images in a 2x5 grid with their corresponding labels.
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.1.1 (Attributes of arrays) - examining array dimensions
# - Week3/NumPy.ipynb: Section 1.1.4 (Reshaping arrays) - understanding image array structure
# - Week3/NumPy.ipynb: Example 2 - image visualization with matplotlib

# %% [markdown]
# #### 14. Analyze the distribution of digits in the dataset. Create a bar chart showing how many samples exist for each digit (0-9). Is the dataset balanced? Calculate the percentage representation of each digit.
#
# **Lecture References:**
# - Week4/Pandas.ipynb: value_counts() method for distribution analysis
# - Week3/NumPy.ipynb: Example 1 - bar chart creation and data visualization
# - Week3/NumPy.ipynb: Section 1.2.5 - percentage calculations

# %% [markdown]
# #### 15. Pixel analysis: Calculate which pixels (positions in the 8x8 grid) have the highest variance across all digit samples. Create a heatmap showing pixel variance. Which areas of the image are most informative for distinguishing between digits?
#
# **Key Functions to Use:**
# - `np.var()` or `np.std()`: Calculate variance or standard deviation across samples
# - `np.reshape()`: Reshape the variance results back to 8x8 grid format
# - `plt.imshow()`: Display the variance as a heatmap
# - `plt.colorbar()`: Add color scale to interpret variance values
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.2.5 (Aggregations) - variance and standard deviation
# - Week3/NumPy.ipynb: Section 1.1.2 (Indexing arrays) - accessing specific array positions
# - Week3/NumPy.ipynb: Example 2 - heatmap visualization techniques

# %% [markdown]
# #### 16. Feature extraction: For each image, calculate summary features:
# - Total pixel intensity (sum of all pixels)
# - Average pixel intensity
# - Number of 'active' pixels (intensity > 8)
# - Standard deviation of pixel intensities
#
# Create box plots showing how these features vary by digit class.
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.2.5 (Aggregations) - sum, mean, std calculations
# - Week3/NumPy.ipynb: Boolean masking for filtering (counting active pixels)
# - Week4/Pandas.ipynb: Statistical analysis and visualization techniques

# %% [markdown]
# ## Section 4: Cross-Dataset Analysis and Advanced Techniques

# %% [markdown]
# #### 17. Dataset comparison: Compare basic characteristics across the three datasets you've worked with:
# - Count the number of samples (rows) and features (columns) for each dataset
# - Identify which dataset has the most features and which has the most samples
# - Create a simple bar chart comparing the number of samples in each dataset
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.1.1 (Attributes of arrays) - shape and size analysis
# - Week4/Pandas.ipynb: DataFrame characteristics and information methods
# - Week3/NumPy.ipynb: Example 1 - basic visualization techniques

# %% [markdown]
# #### 18. Data scaling exercise: Take one feature from the Iris dataset (e.g., sepal length) and try two simple scaling techniques:
# - **Min-Max scaling**: Transform values to range 0-1 using formula: (value - min) / (max - min)
# - **Simple standardization**: Transform values using formula: (value - mean) / std
#
# Compare the original values with the scaled values. What changes and what stays the same?
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.2.5 (Aggregations) - min, max, mean, std calculations
# - Week3/NumPy.ipynb: Section 1.2.1 (Array arithmetic) - basic mathematical operations
# - Week4/Pandas.ipynb: Data transformation techniques

# %% [markdown]
# #### 19. Feature variance analysis: For the diabetes dataset, calculate which features have the highest and lowest variance.
# - Calculate the variance for each feature using `np.var()` or `DataFrame.var()`
# - Create a bar chart showing the variance of each feature
# - Discuss which features vary the most and least across patients
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Section 1.2.5 - variance calculations
# - Week4/Pandas.ipynb: Statistical analysis methods
# - Week3/NumPy.ipynb: Example 1 - bar chart visualization

# %% [markdown]
# #### 20. Simple sampling exercise: From the digits dataset, create two different samples and compare them:
# - **Random sample**: Select 200 random images from the dataset
# - **First 200 sample**: Take just the first 200 images in order
#
# For each sample, count how many of each digit (0-9) you have and create bar charts to compare the distributions. Are they similar or different? What might this tell us about the importance of random sampling?
#
# **Lecture References:**
# - Week3/NumPy.ipynb: Random number generation and array selection
# - Week4/Pandas.ipynb: Data filtering and basic sampling methods
# - Week3/NumPy.ipynb: Example 1 - bar chart creation and comparison
